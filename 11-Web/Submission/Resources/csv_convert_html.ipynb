# %%
import pandas as pd

# %%
data = pd.read_csv("weather_data.csv")
data
# Out:
#               city                                   lat_long   latitude  \
# 0          mataura  (-68.50616938544948, -150.37774696327926) -68.506169
# 1          rikitea  (-30.681296696126786, -126.3156960749132) -30.681297
# 2          bastrop    (32.77746126426588, -91.42701947008482)  32.777461
# 3           hobart   (-76.49871141133052, 152.14258100215392) -76.498711
# 4    pacific grove  (26.160659046051506, -137.22124631442136)  26.160659
# ..             ...                                        ...        ...
# 583         ramona  (33.186424435561705, -116.62408876317744)  33.186424
# 584           tura     (66.23404218169031, 99.14212871649107)  66.234042
# 585           witu   (-2.2018672667641113, 39.40775744690046)  -2.201867
# 586       misratah    (33.49204569393403, 16.076769507459915)  33.492046
# 587          sagae     (38.49539303608708, 140.1829270099998)  38.495393
#
#       longitude  temperature  humidity  cloudiness  wind_speed country  \
# ...

# %%
data.to_html('cities.html')
